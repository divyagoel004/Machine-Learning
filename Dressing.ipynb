# %%
import pandas as pd , numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
inp0=pd.read_csv("C:/Users/divya/Downloads/Attribute+DataSet.csv")

# %%
inp1=pd.read_csv("C:/Users/divya/Downloads/Dress+Sales.csv")

# %%
inp0
# Out:
#        Dress_ID    Style    Price  Rating  Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6     M  Summer     o-neck
# 1    1212192089   Casual      Low     0.0     L  Summer     o-neck
# 2    1190380701  vintage     High     0.0     L  Automn     o-neck
# 3     966005983    Brief  Average     4.6     L  Spring     o-neck
# 4     876339541     cute      Low     4.5     M  Summer     o-neck
# ..          ...      ...      ...     ...   ...     ...        ...
# 474   990559192    Brief  Average     4.7     M  winter     o-neck
# 475   713391965   Casual      Low     4.7     M  Spring     o-neck
# 476   532874347   Casual  Average     4.7     M  Summer     v-neck
# 477   655464934   Casual  Average     4.6     L  winter  boat-neck
# 478   919930954   Casual      Low     4.4  free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# 0      sleevless            NaN     chiffon     ruffles       animal
# ...

# %%
inp0.Size= inp0.Size.replace(['S', 'small', 's'], "Small")

inp0.Size= inp0.Size.replace('free', "Free")

inp0.Size= inp0.Size.replace('M', "Medium")

inp0.Size= inp0.Size.replace('L', "Large") 

inp0.Size= inp0.Size.replace('XL', "Extra large")

# %%
inp0.Size.value_counts(normalize=True)
# Out:
# Medium         0.356994
# Free           0.344468
# Large          0.194154
# Small          0.075157
# Extra large    0.029228
# Name: Size, dtype: float64

# %%
inp1.loc[inp1['09-12-2013']== 'Removed',"09-12-2013"] = np.NaN

inp1.loc[inp1['14-09-2013']== 'removed',"14-09-2013"] = np.NaN

inp1.loc[inp1['16-09-2013']== 'removed',"16-09-2013"] = np.NaN

inp1.loc[inp1['18-09-2013']== 'removed',"18-09-2013"] = np.NaN

inp1.loc[inp1['20-09-2013']== 'removed',"20-09-2013"] = np.NaN

inp1.loc[inp1['22-09-2013']== 'Orders',"22-09-2013"] = np.NaN

# %%
[inp1.isnull().sum()]
# Out:
# [Dress_ID        0
#  29-08-2013      0
#  31-08-2013      0
#  09-02-2013      0
#  09-04-2013      0
#  09-06-2013      0
#  09-08-2013      0
#  09-10-2013      0
#  09-12-2013      1
#  14-09-2013      1
#  16-09-2013      1
#  18-09-2013      1
#  20-09-2013      1
#  22-09-2013      1
#  24-09-2013      0
#  26-09-2013    222
#  28-09-2013      0
#  30-09-2013    257
#  10-02-2013    259
#  10-04-2013    258
#  10-06-2013      0
#  10-08-2013    255
#  10-10-2013    255
#  10-12-2013      0
#  dtype: int64]

# %%
x=np.array(x).reshape(24,1)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 x=np.array(x).reshape(24,1)
#
# NameError: name 'x' is not defined

# %%
x*100/479

# %%
inp1.drop(['10-10-2013'],axis=1,inplace=True)

# %%
[inp1.isnull().sum()]
# Out:
# [Dress_ID        0
#  29-08-2013      0
#  31-08-2013      0
#  09-02-2013      0
#  09-04-2013      0
#  09-06-2013      0
#  09-08-2013      0
#  09-10-2013      0
#  09-12-2013      1
#  14-09-2013      1
#  16-09-2013      1
#  18-09-2013      1
#  20-09-2013      1
#  22-09-2013      1
#  24-09-2013      0
#  26-09-2013    222
#  28-09-2013      0
#  30-09-2013    257
#  10-02-2013    259
#  10-04-2013    258
#  10-06-2013      0
#  10-08-2013    255
#  10-12-2013      0
#  dtype: int64]

# %%
inp1
# Out:
#          Dress_ID  29-08-2013  31-08-2013  09-02-2013  09-04-2013  09-06-2013  \
# 0    1.006033e+09        2114        2274        2491        2660        2727
# 1    1.212192e+09         151         275         570         750         813
# 2    1.190381e+09           6           7           7           7           8
# 3    9.660060e+08        1005        1128        1326        1455        1507
# 4    8.763395e+08         996        1175        1304        1396        1432
# ..            ...         ...         ...         ...         ...         ...
# 474  9.905592e+08           0           0           0          60          62
# 475  7.133920e+08           0           0           0         560         554
# 476  5.328743e+08           0           0           0         734         728
# 477  6.554649e+08           0           0           0         254         259
# 478  9.199310e+08           0           0           0         538         545
#
# ...

# %%
inp1['Spring'] = inp1.apply(lambda x: x['09-04-2013'], axis=1)

inp1['Summer'] = inp1.apply(lambda x: x['29-08-2013'] + x['31-08-2013']+ x['09-06-2013']+ x['09-08-2013']+ x['10-06-2013'], axis=1)

inp1['Winter'] = inp1.apply(lambda x: x['09-02-2013'] + x['09-12-2013']+ x['10-12-2013'], axis=1)

inp1['Autumn'] = inp1.apply(lambda x: x['09-10-2013'] + x['14-09-2013']+ x['16-09-2013']+ x['18-09-2013']+ x['20-09-2013']+ x['22-09-2013']+ x['24-09-2013']+ x['28-09-2013'], axis=1)

# %%
inp1['09-12-2013'] = pd.to_numeric(inp1['09-12-2013'], downcast='float')
inp1['14-09-2013'] = pd.to_numeric(inp1['14-09-2013'], downcast='float')
inp1['16-09-2013'] = pd.to_numeric(inp1['16-09-2013'], downcast='float')
inp1['18-09-2013'] = pd.to_numeric(inp1['18-09-2013'], downcast='float')
inp1['20-09-2013'] = pd.to_numeric(inp1['20-09-2013'], downcast='float')
inp1['22-09-2013'] = pd.to_numeric(inp1['22-09-2013'], downcast='float')

# %%
inp1

# %%
inp1[['Summer','Autumn','Winter','Spring']].sum()
# Out:
# Summer     691907.0
# Autumn    1353543.0
# Winter     473640.0
# Spring     143600.0
# dtype: float64

# %%
inp0 = inp0[~inp0.Price.isnull()]

inp0 = inp0[~inp0.Season.isnull()]

inp0 = inp0[~inp0.NeckLine.isnull()]

inp0 = inp0[~inp0.SleeveLength.isnull()]

inp1 = inp1[~inp1.Winter.isnull()]

inp1 = inp1[~inp1.Autumn.isnull()]

# %%
inp0.Material= inp0.Material.replace(np.nan, "Missing")

inp0.FabricType= inp0.FabricType.replace(np.nan, "Missing")

inp0.Decoration= inp0.Decoration.replace(np.nan, "Missing")

inp0['Pattern Type']= inp0['Pattern Type'].replace(np.nan, "Missing")

# %%
inp0
# Out:
#        Dress_ID    Style    Price  Rating    Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6  Medium  Summer     o-neck
# 1    1212192089   Casual      Low     0.0   Large  Summer     o-neck
# 2    1190380701  vintage     High     0.0   Large  Automn     o-neck
# 3     966005983    Brief  Average     4.6   Large  Spring     o-neck
# 4     876339541     cute      Low     4.5  Medium  Summer     o-neck
# ..          ...      ...      ...     ...     ...     ...        ...
# 474   990559192    Brief  Average     4.7  Medium  winter     o-neck
# 475   713391965   Casual      Low     4.7  Medium  Spring     o-neck
# 476   532874347   Casual  Average     4.7  Medium  Summer     v-neck
# 477   655464934   Casual  Average     4.6   Large  winter  boat-neck
# 478   919930954   Casual      Low     4.4    Free  Summer     v-neck
#
#     SleeveLength       Material  FabricType  Decoration Pattern Type  \
# ...

# %%
inp0.Season= inp0.Season.replace('Automn', "Autumn")

inp0.Season= inp0.Season.replace('spring', "Spring")

inp0.Season= inp0.Season.replace('winter', "Winter")

# %%
inp0.SleeveLength= inp0.SleeveLength.replace(['cap-sleeves', 'capsleeves'], "cap sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace('full', "full sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace(['half','halfsleeve'], "half sleeves")

inp0.SleeveLength= inp0.SleeveLength.replace(['sleevless', 'sleeevless', 'sleeveless', 'sleveless'], "sleeve less")

inp0.SleeveLength= inp0.SleeveLength.replace(['threequarter','threequater', 'thressqatar'], "three quater")

inp0.SleeveLength= inp0.SleeveLength.replace(['turndowncollor','urndowncollor'], "turn down collar")

# %%
inp0.dtypes
# Out:
# Dress_ID            int64
# Style              object
# Price              object
# Rating            float64
# Size               object
# Season             object
# NeckLine           object
# SleeveLength       object
# Material           object
# FabricType         object
# Decoration         object
# Pattern Type       object
# Recommendation      int64
# dtype: object

# %%
inp0.Recommendation.value_counts()
# Out:
# 0    272
# 1    200
# Name: Recommendation, dtype: int64

# %%
inp1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 477 entries, 0 to 478
# Data columns (total 27 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Dress_ID    477 non-null    float64
#  1   29-08-2013  477 non-null    int64
#  2   31-08-2013  477 non-null    int64
#  3   09-02-2013  477 non-null    int64
#  4   09-04-2013  477 non-null    int64
#  5   09-06-2013  477 non-null    int64
#  6   09-08-2013  477 non-null    int64
#  7   09-10-2013  477 non-null    int64
#  8   09-12-2013  477 non-null    float32
#  9   14-09-2013  477 non-null    float32
#  10  16-09-2013  477 non-null    float32
#  11  18-09-2013  477 non-null    float32
#  12  20-09-2013  477 non-null    float32
#  13  22-09-2013  477 non-null    float32
#  14  24-09-2013  477 non-null    int64
#  15  26-09-2013  257 non-null    float64
#  16  28-09-2013  477 non-null    int64
#  17  30-09-2013  222 non-null    float64
#  18  10-02-2013  220 non-null    float64
# ...

# %%
inp0.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 472 entries, 0 to 478
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Dress_ID        472 non-null    int64
#  1   Style           472 non-null    object
#  2   Price           472 non-null    object
#  3   Rating          472 non-null    float64
#  4   Size            472 non-null    object
#  5   Season          472 non-null    object
#  6   NeckLine        472 non-null    object
#  7   SleeveLength    472 non-null    object
#  8   Material        472 non-null    object
#  9   FabricType      472 non-null    object
#  10  Decoration      472 non-null    object
#  11  Pattern Type    472 non-null    object
#  12  Recommendation  472 non-null    int64
# dtypes: float64(1), int64(2), object(10)
# memory usage: 51.6+ KB

# %%
inp0.Style.value_counts()
# Out:
# Casual      217
# Sexy         65
# party        48
# cute         43
# vintage      25
# bohemian     23
# Brief        17
# work         17
# sexy          7
# Novelty       6
# Flare         2
# OL            1
# fashion       1
# Name: Style, dtype: int64

# %%
inp = pd.merge(left=inp0,right=inp1, how='left', left_on='Dress_ID', right_on='Dress_ID')
inp.head()
# Out:
#      Dress_ID    Style    Price  Rating    Size  Season NeckLine  \
# 0  1006032852     Sexy      Low     4.6  Medium  Summer   o-neck
# 1  1212192089   Casual      Low     0.0   Large  Summer   o-neck
# 2  1190380701  vintage     High     0.0   Large  Autumn   o-neck
# 3   966005983    Brief  Average     4.6   Large  Spring   o-neck
# 4   876339541     cute      Low     4.5  Medium  Summer   o-neck
#
#    SleeveLength       Material FabricType  ... 30-09-2013_y 10-02-2013_y  \
# 0   sleeve less        Missing    chiffon  ...       3746.0       3795.0
# 1         Petal     microfiber    Missing  ...       3354.0       3475.0
# 2  full sleeves       polyster    Missing  ...         11.0         11.0
# 3  full sleeves           silk    chiffon  ...       1924.0       1929.0
# 4     butterfly  chiffonfabric    chiffon  ...       2312.0       2387.0
#
#    10-04-2013_y  10-06-2013_y  10-08-2013_y  10-12-2013_y  Spring_y  Summer_y  \
# ...

# %%
inp0.drop(inp0.loc[:,'29-08-2013':'10-12-2013'].columns, axis= 1, inplace= True)
inp0.isnull().sum()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_3548\2498300549.py:1: UserWarning: Parsing dates in DD/MM/YYYY format when dayfirst=False (the default) was specified. This may lead to inconsistently parsed dates! Specify a format to ensure consistent parsing.
#   inp0.drop(inp0.loc[:,'29-08-2013':'10-12-2013'].columns, axis= 1, inplace= True)
# Dress_ID          0
# Style             0
# Price             0
# Rating            0
# Size              0
# Season            0
# NeckLine          0
# SleeveLength      0
# Material          0
# FabricType        0
# Decoration        0
# Pattern Type      0
# Recommendation    0
# Spring            1
# Summer            1
# Winter            1
# Autumn            1
# dtype: int64

# %%
total_collection=inp0.groupby(['Style'])['Spring','Winter','Autumn', 'Summer'].sum()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_3548\301247636.py:1: FutureWarning: Indexing with multiple keys (implicitly converted to a tuple of keys) will be deprecated, use a list instead.
#   total_collection=inp0.groupby(['Style'])['Spring','Winter','Autumn', 'Summer'].sum()

# %%
total_collection[total_collection.sum(axis= 1)<50000]
# Out:
#          Spring  Winter  Autumn  Summer
# Style
# Flare      71.0   406.0  1161.0   451.0
# Novelty   563.0  2504.0  7353.0  2866.0
# OL         15.0    53.0   158.0    63.0
# fashion    19.0    74.0   211.0    91.0

# %%
inp0.replace(total_collection[total_collection.sum(axis=1)<50000].index, 'Others', inplace=True)

# %%
inp0.Style.value_counts(normalize=True)
# Out:
# Casual      0.459746
# Sexy        0.137712
# party       0.101695
# cute        0.091102
# vintage     0.052966
# bohemian    0.048729
# Brief       0.036017
# work        0.036017
# Others      0.021186
# sexy        0.014831
# Name: Style, dtype: float64

# %%
inp0.Autumn.describe()
# Out:
# count      471.000000
# mean      2852.849257
# std       5037.033044
# min          1.000000
# 25%        410.500000
# 50%       1334.000000
# 75%       3126.000000
# max      55532.000000
# Name: Autumn, dtype: float64

# %%
inp0['Autumn'].quantile([0.99,1])
# Out:
# 0.99    24134.0
# 1.00    55532.0
# Name: Autumn, dtype: float64

# %%
55532-24134
# Out:
# 31398

# %%
inp0
# Out:
#        Dress_ID    Style    Price  Rating    Size  Season   NeckLine  \
# 0    1006032852     Sexy      Low     4.6  Medium  Summer     o-neck
# 1    1212192089   Casual      Low     0.0   Large  Summer     o-neck
# 2    1190380701  vintage     High     0.0   Large  Autumn     o-neck
# 3     966005983    Brief  Average     4.6   Large  Spring     o-neck
# 4     876339541     cute      Low     4.5  Medium  Summer     o-neck
# ..          ...      ...      ...     ...     ...     ...        ...
# 467   990559192    Brief  Average     4.7  Medium  Winter     o-neck
# 468   713391965   Casual      Low     4.7  Medium  Spring     o-neck
# 469   532874347   Casual  Average     4.7  Medium  Summer     v-neck
# 470   655464934   Casual  Average     4.6   Large  Winter  boat-neck
# 471   919930954   Casual      Low     4.4    Free  Summer     v-neck
#
#      SleeveLength       Material  FabricType  Decoration Pattern Type  \
# ...

# %%
inp0["Price"].value_counts(normalize=True)
# Out:
# Average      0.504237
# Low          0.343220
# Medium       0.063559
# High         0.044492
# very-high    0.044492
# Name: Price, dtype: float64

# %%
print(inp0.groupby('Price')['Rating'].mean())
# Out:
# Price
# Average      3.455042
# High         2.914286
# Low          3.731481
# Medium       3.156667
# very-high    3.123810
# Name: Rating, dtype: float64

# %%
inp0.groupby('Style')['Rating'].median()
# Out:
# Style
# Brief       4.6
# Casual      4.6
# Others      0.0
# Sexy        4.6
# bohemian    4.6
# cute        4.6
# party       4.7
# sexy        4.5
# vintage     4.6
# work        4.7
# Name: Rating, dtype: float64

# %%
x=inp0[["Spring","Autumn","Winter","Summer","Recommendation"]].corr()

# %%
sns.heatmap(x,annot=True)
# Out:
# <Axes: >

# %%
print(inp0.groupby('Recommendation')[['Autumn',"Spring","Summer","Winter"]].mean())
# Out:
#                      Autumn      Spring       Summer       Winter
# Recommendation
# 0               2841.720588  298.209559  1433.547794   987.654412
# 1               2868.060302  303.658291  1469.899497  1002.809045

# %%
inp0.groupby('Size')["Recommendation"].mean().plot.bar()
# Out:
# <Axes: xlabel='Size'>

# %%
inp0.groupby(by="Price")["Recommendation"].mean().plot.bar()
# Out:
# <Axes: xlabel='Price'>

# %%
inp0.groupby(by="Style")["Recommendation"].mean().plot.bar()
# Out:
# <Axes: xlabel='Style'>

# %%
res = pd.pivot_table(data=inp0, index="Style", columns="Price", values="Recommendation")

sns.heatmap(res, cmap="RdYlGn", annot=True, center=0.427)

plt.show()

# %%
res = pd.pivot_table(data=inp0, index="Material", columns='Season', values="Recommendation")

sns.heatmap(res, cmap="RdYlGn", annot=True)

plt.show()
