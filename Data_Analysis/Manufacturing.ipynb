# %%
import numpy as np,pandas as pd,matplotlib.pyplot as plt,seaborn as sns

# %%
df=pd.read_csv("C:/Users/divya/Downloads/economic-survey-of-manufacturing-sept-2023-csv.csv")

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0          MFGQ.SFA1CA  1992.12    2493.370        NaN      F  Dollars
# 1          MFGQ.SFA1CA  1993.03    3209.200        NaN      F  Dollars
# 2          MFGQ.SFA1CA  1993.06    2780.170        NaN      F  Dollars
# 3          MFGQ.SFA1CA  1993.09    1933.010        NaN      F  Dollars
# 4          MFGQ.SFA1CA  1993.12    2692.920        NaN      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 28633      MFGQ.SFZ5KA  2022.09    9118.318        NaN      F  Dollars
# 28634      MFGQ.SFZ5KA  2022.12   10080.758        NaN      F  Dollars
# 28635      MFGQ.SFZ5KA  2023.03   10682.458        NaN      F  Dollars
# 28636      MFGQ.SFZ5KA  2023.06    9023.253        NaN      F  Dollars
# 28637      MFGQ.SFZ5KA  2023.09    8922.748        NaN      F  Dollars
#
#        Magnitude                                Subject  \
# 0              6  Manufacturing Survey (ANZSIC06) - MFG
# ...

# %%
df.shape
# Out:
# (28638, 14)

# %%
df.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# Suppressed           object
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# Series_title_4       object
# Series_title_5       object
# dtype: object

# %%
df.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value           1649
# Suppressed          28636
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3          0
# Series_title_4          0
# Series_title_5      27252
# dtype: int64

# %%
df[df['Data_value'].isnull()]
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 244        MFGQ.SFA1CS  1992.12         NaN        NaN      C  Dollars
# 245        MFGQ.SFA1CS  1993.03         NaN        NaN      C  Dollars
# 246        MFGQ.SFA1CS  1993.06         NaN        NaN      C  Dollars
# 247        MFGQ.SFA1CS  1993.09         NaN        NaN      C  Dollars
# 248        MFGQ.SFA1CS  1993.12         NaN        NaN      C  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 28267      MFGQ.SFZ2KT  2022.09         NaN        NaN      C  Dollars
# 28268      MFGQ.SFZ2KT  2022.12         NaN        NaN      C  Dollars
# 28269      MFGQ.SFZ2KT  2023.03         NaN        NaN      C  Dollars
# 28270      MFGQ.SFZ2KT  2023.06         NaN        NaN      C  Dollars
# 28271      MFGQ.SFZ2KT  2023.09         NaN        NaN      C  Dollars
#
#        Magnitude                                Subject  \
# 244            6  Manufacturing Survey (ANZSIC06) - MFG
# ...

# %%
df['Data_value'].value_counts()
# Out:
# 1.000       27
# 1.300       25
# 1.100       24
# 0.500       22
# 0.800       22
#             ..
# 2039.699     1
# 1912.540     1
# 1743.064     1
# 2018.994     1
# 8922.748     1
# Name: Data_value, Length: 24511, dtype: int64

# %%
df['Data_value'].mode()
# Out:
# 0    1.0
# Name: Data_value, dtype: float64

# %%
df['Data_value'].fillna(method='ffill',inplace=True)

# %%
df['Data_value'].isnull().sum()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value              0
# Suppressed          28636
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3          0
# Series_title_4          0
# Series_title_5      27252
# dtype: int64

# %%
df["Suppressed"].value_counts()
# Out:
# Y    2
# Name: Suppressed, dtype: int64

# %%
df['Suppressed'].fillna('N',inplace=True)

# %%
df['Series_title_5'].value_counts()
# Out:
# Percentage change from same period previous year    702
# Percentage change from previous period              684
# Name: Series_title_5, dtype: int64

# %%
df.isnull().sum()
# Out:
# Series_reference        0
# Period                  0
# Data_value              0
# Suppressed              0
# STATUS                  0
# UNITS                   0
# Magnitude               0
# Subject                 0
# Group                   0
# Series_title_1          0
# Series_title_2          0
# Series_title_3          0
# Series_title_4          0
# Series_title_5      27252
# dtype: int64

# %%
df.dtypes
# Out:
# Series_reference     object
# Period              float64
# Data_value          float64
# Suppressed           object
# STATUS               object
# UNITS                object
# Magnitude             int64
# Subject              object
# Group                object
# Series_title_1       object
# Series_title_2       object
# Series_title_3       object
# Series_title_4       object
# Series_title_5       object
# dtype: object

# %%
df.head()
# Out:
#   Series_reference   Period  Data_value Suppressed STATUS    UNITS  Magnitude  \
# 0      MFGQ.SFA1CA  1992.12     2493.37          N      F  Dollars          6
# 1      MFGQ.SFA1CA  1993.03     3209.20          N      F  Dollars          6
# 2      MFGQ.SFA1CA  1993.06     2780.17          N      F  Dollars          6
# 3      MFGQ.SFA1CA  1993.09     1933.01          N      F  Dollars          6
# 4      MFGQ.SFA1CA  1993.12     2692.92          N      F  Dollars          6
#
#                                  Subject  \
# 0  Manufacturing Survey (ANZSIC06) - MFG
# 1  Manufacturing Survey (ANZSIC06) - MFG
# 2  Manufacturing Survey (ANZSIC06) - MFG
# 3  Manufacturing Survey (ANZSIC06) - MFG
# 4  Manufacturing Survey (ANZSIC06) - MFG
#
#                                                Group  \
# 0  Industry by variable - Subannual Financial Col...
# 1  Industry by variable - Subannual Financial Col...
# 2  Industry by variable - Subannual Financial Col...
# ...

# %%
df['UNITS'].value_counts()
# Out:
# Dollars    27252
# PERCENT     1386
# Name: UNITS, dtype: int64

# %%
df["Magnitude"].value_counts()
# Out:
# 6    27252
# 0     1386
# Name: Magnitude, dtype: int64

# %%
sns.pairplot(data=df,hue='STATUS',kind='scatter')

# %%
help(sns.pairplot)
# Out:
# Help on function pairplot in module seaborn.axisgrid:
#
# pairplot(data, *, hue=None, hue_order=None, palette=None, vars=None, x_vars=None, y_vars=None, kind='scatter', diag_kind='auto', markers=None, height=2.5, aspect=1, corner=False, dropna=False, plot_kws=None, diag_kws=None, grid_kws=None, size=None)
#     Plot pairwise relationships in a dataset.
#
#     By default, this function will create a grid of Axes such that each numeric
#     variable in ``data`` will by shared across the y-axes across a single row and
#     the x-axes across a single column. The diagonal plots are treated
#     differently: a univariate distribution plot is drawn to show the marginal
#     distribution of the data in each column.
#
#     It is also possible to show a subset of variables or plot different
#     variables on the rows and columns.
#
#     This is a high-level interface for :class:`PairGrid` that is intended to
# ...

# %%
df['Subject'].value_counts().plot.barh()
# Out:
# <Axes: >

# %%
df['Group'].value_counts().plot.barh()
# Out:
# <Axes: >

# %%
df['Series_title_1'].value_counts()
# Out:
# Meat and dairy product manufacturing                           2280
# All manufacturing excluding meat and dairy                     2280
# All manufacturing                                              2280
# Seafood processing                                             1818
# Fruit, oil, cereal, and other food manufacturing               1818
# Beverage and tobacco product manufacturing                     1818
# Textile, leather, clothing, and footwear manufacturing         1818
# Wood and paper product manufacturing                           1818
# Printing                                                       1818
# Chemical, polymer, and rubber product manufacturing            1818
# Non-metallic mineral product manufacturing                     1818
# Metal product manufacturing                                    1818
# Transport equipment, machinery, and equipment manufacturing    1818
# Furniture and other manufacturing                              1818
# ...

# %%
df['Series_title_2'].value_counts()
# Out:
# Sales (operating income)                                        12276
# Purchases and operating expenditure                             10890
# Stocks of finished goods, trading goods and work in progress     3621
# Stocks of raw materials for use in production                    1851
# Name: Series_title_2, dtype: int64

# %%
df['Series_title_3'].value_counts()
# Out:
# Current prices                                15564
# Deflated, at September 2010 quarter prices    13074
# Name: Series_title_3, dtype: int64

# %%
df['Series_title_4'].value_counts()
# Out:
# Unadjusted             13434
# Seasonally adjusted     7944
# Trend                   7260
# Name: Series_title_4, dtype: int64

# %%
df['Series_title_5'].value_counts()
# Out:
# Percentage change from same period previous year    702
# Percentage change from previous period              684
# Name: Series_title_5, dtype: int64

# %%
df.rename({'Series_title_3':"Value",'Series_title_4':"Season",'Series_title_5':"%_change"},inplace=True,axis=1)

# %%
df
# Out:
#       Series_reference   Period  Data_value Suppressed STATUS    UNITS  \
# 0          MFGQ.SFA1CA  1992.12    2493.370          N      F  Dollars
# 1          MFGQ.SFA1CA  1993.03    3209.200          N      F  Dollars
# 2          MFGQ.SFA1CA  1993.06    2780.170          N      F  Dollars
# 3          MFGQ.SFA1CA  1993.09    1933.010          N      F  Dollars
# 4          MFGQ.SFA1CA  1993.12    2692.920          N      F  Dollars
# ...                ...      ...         ...        ...    ...      ...
# 28633      MFGQ.SFZ5KA  2022.09    9118.318          N      F  Dollars
# 28634      MFGQ.SFZ5KA  2022.12   10080.758          N      F  Dollars
# 28635      MFGQ.SFZ5KA  2023.03   10682.458          N      F  Dollars
# 28636      MFGQ.SFZ5KA  2023.06    9023.253          N      F  Dollars
# 28637      MFGQ.SFZ5KA  2023.09    8922.748          N      F  Dollars
#
#        Magnitude                                Subject  \
# 0              6  Manufacturing Survey (ANZSIC06) - MFG
# ...

# %%
df.groupby(by='Products')['Series_title_2'].value_counts().plot.pie()
# Out:
# <Axes: ylabel='Series_title_2'>

# %%
df['%_change'].value_counts(dropna=False,normalize=True).plot.pie()
# Out:
# <Axes: ylabel='%_change'>

# %%
df['%_change'].dtype
# Out:
# dtype('O')

# %%
res=df[['Data_value','Magnitude']].corr()

# %%
sns.heatmap(res,annot=True,cmap='Greens')
# Out:
# <Axes: >

# %%
g=df.groupby(by='Series_reference')

# %%
g.mean()
# Out:
# C:\Users\divya\AppData\Local\Temp\ipykernel_2932\2978112660.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   g.mean()
#                     Period    Data_value  Magnitude
# Series_reference
# MFGQ.SFA1CA       2007.825   5821.335766        6.0
# MFGQ.SFA1CAAC     2008.325      5.770000        0.0
# MFGQ.SFA1CS       2007.825   5639.415637        6.0
# MFGQ.SFA1CSPC     2009.075      1.533333        0.0
# MFGQ.SFA1CT       2007.825   5523.431694        6.0
# ...                    ...           ...        ...
# MFGQ.SFZ2KS       2008.575  17897.734347        6.0
# MFGQ.SFZ2KT       2008.575  18056.754475        6.0
# MFGQ.SFZ4CA       2007.825   3725.973661        6.0
# MFGQ.SFZ5CA       2007.825   7786.976000        6.0
# MFGQ.SFZ5KA       2008.575   8686.945364        6.0
#
# ...
