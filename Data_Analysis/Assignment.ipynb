# %%
import pandas as pd,numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
s=pd.read_csv("C:/Users/divya/Downloads/Movie+Assignment+Data.csv")

# %%
import warnings

warnings.filterwarnings('ignore')

# %%
s
# Out:
#                                            Title  title_year     budget  \
# 0                                     La La Land        2016   30000000
# 1                                       Zootopia        2016  150000000
# 2                                           Lion        2016   12000000
# 3                                        Arrival        2016   47000000
# 4                          Manchester by the Sea        2016    9000000
# ..                                           ...         ...        ...
# 95                                      Whiplash        2014    3300000
# 96                               Before Midnight        2013    3000000
# 97    Star Wars: Episode VII - The Force Awakens        2015  245000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
#
#         Gross              actor_1_name        actor_2_name  \
# ...

# %%
s.shape
# Out:
# (100, 62)

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 62 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
s.describe()
# Out:
#         title_year        budget         Gross  actor_1_facebook_likes  \
# count   100.000000  1.000000e+02  1.000000e+02              100.000000
# mean   2012.820000  7.838400e+07  1.468679e+08            13407.270000
# std       1.919491  7.445295e+07  1.454004e+08            10649.037862
# min    2010.000000  3.000000e+06  2.238380e+05               39.000000
# 25%    2011.000000  1.575000e+07  4.199752e+07             1000.000000
# 50%    2013.000000  4.225000e+07  1.070266e+08            13000.000000
# 75%    2014.000000  1.500000e+08  2.107548e+08            20000.000000
# max    2016.000000  2.600000e+08  9.366622e+08            35000.000000
#
#        actor_2_facebook_likes  actor_3_facebook_likes  IMDb_rating  \
# count               99.000000               98.000000   100.000000
# mean              7377.303030             3002.153061     7.883000
# std              13471.568216             6940.301133     0.247433
# ...

# %%
s["budget"].apply(lambda x : x/1000000)
# Out:
# 0      30.0
# 1     150.0
# 2      12.0
# 3      47.0
# 4       9.0
#       ...
# 95      3.3
# 96      3.0
# 97    245.0
# 98    150.0
# 99      5.0
# Name: budget, Length: 100, dtype: float64

# %%
s["Gross"].apply(lambda x: x/1000000)
# Out:
# 0     151.101803
# 1     341.268248
# 2      51.738905
# 3     100.546139
# 4      47.695371
#          ...
# 95     13.092000
# 96      8.114507
# 97    936.662225
# 98    296.347721
# 99      0.223838
# Name: Gross, Length: 100, dtype: float64

# %%
s["Profit"]=s["Gross"]-s["budget"]

# %%
s["Profit"]
# Out:
# 0     121101803
# 1     191268248
# 2      39738905
# 3      53546139
# 4      38695371
#         ...
# 95      9792000
# 96      5114507
# 97    691662225
# 98    146347721
# 99     -4776162
# Name: Profit, Length: 100, dtype: int64

# %%
s.sort_values(by="Profit")
# Out:
#                                          Title  title_year     budget  \
# 22                                        Hugo        2011  170000000
# 39                           The Little Prince        2015   81200000
# 17                            Edge of Tomorrow        2014  178000000
# 7                                      Tangled        2010  260000000
# 46                 Scott Pilgrim vs. the World        2010   60000000
# ..                                         ...         ...        ...
# 12                                 Toy Story 3        2010  200000000
# 32             The Hunger Games: Catching Fire        2013  130000000
# 47                                    Deadpool        2016   58000000
# 11                                The Avengers        2012  220000000
# 97  Star Wars: Episode VII - The Force Awakens        2015  245000000
#
#         Gross         actor_1_name       actor_2_name           actor_3_name  \
# ...

# %%
d=s.sort_values(by="Profit",ascending=False).head(10)

# %%
d
# Out:
#                                          Title  title_year     budget  \
# 97  Star Wars: Episode VII - The Force Awakens        2015  245000000
# 11                                The Avengers        2012  220000000
# 47                                    Deadpool        2016   58000000
# 32             The Hunger Games: Catching Fire        2013  130000000
# 12                                 Toy Story 3        2010  200000000
# 8                        The Dark Knight Rises        2012  250000000
# 45                              The Lego Movie        2014   60000000
# 1                                     Zootopia        2016  150000000
# 41                               Despicable Me        2010   69000000
# 18                                  Inside Out        2015  175000000
#
#         Gross       actor_1_name       actor_2_name           actor_3_name  \
# 97  936662225        Doug Walker         Rob Walker                      0
# ...

# %%
plt.scatter(s.Profit,s.budget,alpha=0.7,s=10)

# %%
sns.jointplot(data=s,x="Profit",y="budget",kind='scatter')

# %%
neg_profit=s[s["Profit"]<0]

# %%
neg_profit
# Out:
#                           Title  title_year     budget      Gross  \
# 7                       Tangled        2010  260000000  200807262
# 17             Edge of Tomorrow        2014  178000000  100189501
# 22                         Hugo        2011  170000000   73820094
# 28           X-Men: First Class        2011  160000000  146405371
# 39            The Little Prince        2015   81200000    1339152
# 46  Scott Pilgrim vs. the World        2010   60000000   31494270
# 56                         Rush        2013   38000000   26903709
# 66                      Warrior        2011   25000000   13651662
# 82                      Flipped        2010   14000000    1752214
# 89                        Amour        2012    8900000     225377
# 99      Tucker and Dale vs Evil        2010    5000000     223838
#
#            actor_1_name        actor_2_name            actor_3_name  \
# 7          Brad Garrett        Donna Murphy             M.C. Gainey
# ...

# %%
neg_profit["Title"]
# Out:
# 7                         Tangled
# 17               Edge of Tomorrow
# 22                           Hugo
# 28             X-Men: First Class
# 39              The Little Prince
# 46    Scott Pilgrim vs. the World
# 56                           Rush
# 66                        Warrior
# 82                        Flipped
# 89                          Amour
# 99        Tucker and Dale vs Evil
# Name: Title, dtype: object

# %%
s["MetaCritic"]=s["MetaCritic"].apply(lambda x: x/10)

# %%
s['Avg_rating']=s.loc[:,["MetaCritic","IMDb_rating"]].mean(axis=1)

# %%
x=s.sort_values(by="Avg_rating",ascending=False)

# %%
x
# Out:
#                                            Title  title_year     budget  \
# 94                                       Boyhood        2014    4000000
# 69                              12 Years a Slave        2013   20000000
# 18                                    Inside Out        2015  175000000
# 4                          Manchester by the Sea        2016    9000000
# 0                                     La La Land        2016   30000000
# ..                                           ...         ...        ...
# 59                                      Kick-Ass        2010   30000000
# 98  Harry Potter and the Deathly Hallows: Part I        2010  150000000
# 99                       Tucker and Dale vs Evil        2010    5000000
# 42                                          Fury        2014   68000000
# 44                               Les Mis̩rables        2012   61000000
#
#         Gross        actor_1_name        actor_2_name     actor_3_name  \
# ...

# %%
s["MetaCritic"]-s["IMDb_rating"]<0.5
# Out:
# 94    False
# 69    False
# 4     False
# 34    False
# 53    False
#       ...
# 16    False
# 88    False
# 82    False
# 71    False
# 52    False
# Length: 100, dtype: bool

# %%
UniversalAcclaim=s[(abs(s["MetaCritic"]-s["IMDb_rating"])<0.5) & (s["Avg_rating"]>=8)]

# %%
s["Avg_rating"]>8
# Out:
# 94     True
# 69     True
# 4      True
# 34     True
# 53     True
#       ...
# 16    False
# 88    False
# 82    False
# 71    False
# 52    False
# Name: Avg_rating, Length: 100, dtype: bool

# %%
s["Avg_rating"]
# Out:
# 94    8.95
# 69    8.85
# 4     8.75
# 34    8.70
# 53    8.60
#       ...
# 16    7.90
# 88    7.80
# 82    7.70
# 71    7.60
# 52    7.50
# Name: Avg_rating, Length: 100, dtype: float64

# %%
s[['actor_1_name','actor_1_facebook_likes']]
# Out:
#           actor_1_name  actor_1_facebook_likes
# 94      Ellar Coltrane                     230
# 69  Quvenzhan̩ Wallis                    2000
# 4        Casey Affleck                     518
# 34      Phaldut Sharma                      39
# 53     Andrew Garfield                   10000
# ..                 ...                     ...
# 16        Aidan Turner                    5000
# 88          Tom Hughes                     565
# 82    Madeline Carroll                    1000
# 71        Emily Watson                     876
# 52       Jerry Ferrara                     480
#
# [100 rows x 2 columns]

# %%
s["Popular"]=s["actor_1_facebook_likes"]+s["actor_2_facebook_likes"]+s["actor_3_facebook_likes"]

# %%
s["Popular"].value_counts()
# Out:
# 36000.0    3
# 6745.0     2
# 44000.0    2
# 51000.0    2
# 550.0      1
#           ..
# 40265.0    1
# 14128.0    1
# 895.0      1
# 11865.0    1
# 1056.0     1
# Name: Popular, Length: 92, dtype: int64

# %%
s.sort_values(by="Popular",ascending=False).head(5)
# Out:
#                          Title  title_year     budget      Gross  \
# 2                         Lion        2016   12000000   51738905
# 27                   Inception        2010  160000000  292568851
# 14  X-Men: Days of Future Past        2014  200000000  233914986
# 4        Manchester by the Sea        2016    9000000   47695371
# 8        The Dark Knight Rises        2012  250000000  448130642
#
#          actor_1_name        actor_2_name          actor_3_name  \
# 2           Dev Patel       Nicole Kidman           Rooney Mara
# 27  Leonardo DiCaprio           Tom Hardy  Joseph Gordon-Levitt
# 14  Jennifer Lawrence      Peter Dinklage          Hugh Jackman
# 4       Casey Affleck  Michelle Williams          Kyle Chandler
# 8           Tom Hardy      Christian Bale  Joseph Gordon-Levitt
#
#     actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 2                    33000                 96000.0                  9800.0
# ...

# %%
s[((s['actor_1_facebook_likes']>=s['actor_2_facebook_likes']/2) |
  ( s['actor_1_facebook_likes']>=s['actor_3_facebook_likes']/2))
  & ((s['actor_2_facebook_likes']>=s['actor_1_facebook_likes']/2) |
     (s['actor_2_facebook_likes']>=s['actor_3_facebook_likes']/2)) &
 ( (s['actor_3_facebook_likes']>=s['actor_2_facebook_likes']/2) | 
   (s['actor_3_facebook_likes']>=s['actor_1_facebook_likes']/2))]
# Out:
#                                            Title  title_year     budget  \
# 34                                       Gravity        2013  100000000
# 96                               Before Midnight        2013    3000000
# 80                                    Ex Machina        2014   15000000
# 94                                       Boyhood        2014    4000000
# 60                                       Sicario        2015   30000000
# 74                             Midnight in Paris        2011   17000000
# 61                        Straight Outta Compton        2015   28000000
# 59                                      Kick-Ass        2010   30000000
# 89                                         Amour        2012    8900000
# 7                                        Tangled        2010  260000000
# 71                                The Book Thief        2013   19000000
# 86                                     Philomena        2013   12000000
# ...

# %%
s["Runtime"]
# Out:
# 34     91
# 97    136
# 96    109
# 80    108
# 94    165
#      ...
# 27    148
# 2     118
# 0     128
# 3     116
# 6     115
# Name: Runtime, Length: 100, dtype: int64

# %%
plt.hist(s["Runtime"],edgecolor="Orange")
# Out:
# (array([ 6., 13., 12., 28., 14.,  9.,  8.,  4.,  5.,  1.]),
#  array([ 91. ,  99.9, 108.8, 117.7, 126.6, 135.5, 144.4, 153.3, 162.2,
#         171.1, 180. ]),
#  <BarContainer object of 10 artists>)

# %%
sns.distplot(s.Runtime)
# Out:
# <Axes: xlabel='Runtime', ylabel='Density'>

# %%
s.sort_values(by="CVotesU18")s[]
# Out:
#                       Title  title_year     budget      Gross  \
# 89                    Amour        2012    8900000     225377
# 86                Philomena        2013   12000000   37707719
# 87                 Nebraska        2013   12000000   17613460
# 96          Before Midnight        2013    3000000    8114507
# 99  Tucker and Dale vs Evil        2010    5000000     223838
# ..                      ...         ...        ...        ...
# 8     The Dark Knight Rises        2012  250000000  448130642
# 11             The Avengers        2012  220000000  623279547
# 19  Guardians of the Galaxy        2014  170000000  333130696
# 27                Inception        2010  160000000  292568851
# 26             Interstellar        2014  165000000  187991439
#
#                 actor_1_name       actor_2_name            actor_3_name  \
# 89          Isabelle Huppert    Emmanuelle Riva  Jean-Louis Trintignant
# 86              Steve Coogan    Mare Winningham           Peter Hermann
# ...

# %%
Popular=s[(s["content_rating"]=='R')]

# %%
Popular.sort_values(by="CVotesU18",ascending=False,ignore_index=True).head(10)
# Out:
#                                              Title  title_year     budget  \
# 0                                         Deadpool        2016   58000000
# 1                          The Wolf of Wall Street        2013  100000000
# 2                                 Django Unchained        2012  100000000
# 3                               Mad Max: Fury Road        2015  150000000
# 4                                         Whiplash        2014    3300000
# 5                                     The Revenant        2015  135000000
# 6                                   Shutter Island        2010   80000000
# 7                                        Gone Girl        2014   61000000
# 8                         The Grand Budapest Hotel        2014   25000000
# 9  Birdman or (The Unexpected Virtue of Ignorance)        2014   18000000
#
#        Gross       actor_1_name         actor_2_name       actor_3_name  \
# 0  363024263      Ryan Reynolds            Ed Skrein     Stefan Kapicic
# ...

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 34 to 6
# Data columns (total 66 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
column_list=[]
for i in s.columns:
    if i.startswith('ge')|i.startswith("CV")|i.startswith("V"):
        column_list.append(i)

# %%
df=s.loc[:,column_list]

# %%
df
# Out:
#       genre_1    genre_2   genre_3  CVotes10  CVotes09  CVotes08  CVotes07  \
# 34      Drama     Sci-Fi  Thriller     89986    127616    169693    122275
# 97     Action  Adventure   Fantasy    155391    161810    166378     99402
# 96      Drama    Romance       NaN     16953     22109     31439     19251
# 80      Drama    Mystery    Sci-Fi     29780     64769    123938     82736
# 94      Drama        NaN       NaN     49673     62055     76838     52238
# ..        ...        ...       ...       ...       ...       ...       ...
# 27     Action  Adventure    Sci-Fi    584839    485218    304457    130972
# 2   Biography      Drama       NaN     23325     29830     40564     20296
# 0      Comedy      Drama     Music     74245     71191     64640     38831
# 3       Drama    Mystery    Sci-Fi     55533     87850    109536     65440
# 6      Action  Adventure   Fantasy     38952     51465    102744     83322
#
# ...

# %%
df['cnt']=1

# %%
df_by_g1=df.groupby("genre_1")

# %%
df_by_g2=df.groupby("genre_2")

# %%
df_by_g3=df.groupby("genre_3")

# %%
df_by_g1=pd.DataFrame(df_by_g1.sum())

# %%
df_by_g2=pd.DataFrame(df_by_g2.sum())

# %%
df_by_g3=pd.DataFrame(df_by_g3.sum())

# %%
x=df_by_g1.add(df_by_g2,fill_value=0)

# %%
y=x.add(df_by_g3,fill_value=0)

# %%
genre_top10=y[y["cnt"]>=10]

# %%
genre_top10
c=genre_top10["cnt"]

# %%
genre_top10=genre_top10.div(genre_top10["cnt"],axis="index")

# %%
genre_top10.apply(lambda x :  round(x,2),axis=0)
# Out:
#             CVotes10   CVotes09   CVotes08   CVotes07  CVotes06  CVotes05  \
# Action     102144.10  114433.19  150895.32   94262.13  34688.84  12693.03
# Adventure   94596.29  105636.63  138482.32   86367.92  31896.71  11551.84
# Animation   61960.18   72566.09  104837.64   65707.45  22825.09   7551.73
# Biography   47333.50   77867.11  123948.78   74054.44  23644.17   7702.67
# Comedy      60157.22   77173.35  108993.52   69176.91  26099.43   9863.13
# Crime       52229.64   87919.82  129045.00   74671.82  25308.27   8971.82
# Drama       52375.97   75928.85  109339.28   66456.92  23528.55   8497.11
# Romance     42304.54   53037.85   82252.31   54833.92  21637.62   8530.85
# Sci-Fi     136781.41  148873.82  176646.71  106005.76  39518.29  14951.47
# Thriller    83207.77  112730.08  153336.77   90446.08  32003.54  11534.85
#
#            CVotes04  CVotes03  CVotes02  CVotes01  ...  Votes3044  Votes3044M  \
# ...

# %%
genre_top10.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10 entries, Action to Thriller
# Data columns (total 45 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   CVotes10      10 non-null     float64
#  1   CVotes09      10 non-null     float64
#  2   CVotes08      10 non-null     float64
#  3   CVotes07      10 non-null     float64
#  4   CVotes06      10 non-null     float64
#  5   CVotes05      10 non-null     float64
#  6   CVotes04      10 non-null     float64
#  7   CVotes03      10 non-null     float64
#  8   CVotes02      10 non-null     float64
#  9   CVotes01      10 non-null     float64
#  10  CVotesMale    10 non-null     float64
#  11  CVotesFemale  10 non-null     float64
#  12  CVotesU18     10 non-null     float64
#  13  CVotesU18M    10 non-null     float64
#  14  CVotesU18F    10 non-null     float64
#  15  CVotes1829    10 non-null     float64
#  16  CVotes1829M   10 non-null     float64
# ...

# %%
genre_top10["cnt"]=c

# %%
plt.figure(figsize=[8,4])
sns.barplot(x=genre_top10.index,y=genre_top10.cnt)
# Out:
# <Axes: ylabel='cnt'>

# %%
m=genre_top10.index

# %%
# Out:
# Index(['Action', 'Adventure', 'Animation', 'Biography', 'Comedy', 'Crime',
#        'Drama', 'Romance', 'Sci-Fi', 'Thriller'],
#       dtype='object')

# %%
genre_top10.cnt
# Out:
# Action       1.0
# Adventure    1.0
# Animation    1.0
# Biography    1.0
# Comedy       1.0
# Crime        1.0
# Drama        1.0
# Romance      1.0
# Sci-Fi       1.0
# Thriller     1.0
# Name: cnt, dtype: float64

# %%
genre_top10
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Action     34688.838710  12693.032258  5386.129032  3064.645161  2115.258065
# ...

# %%
d=[]
for i in genre_top10.columns:
    if (i.endswith("M")|i.endswith("m"))&(i.startswith("C")):
        d.append(i)
        
d
# Out:
# ['CVotesU18M', 'CVotes1829M', 'CVotes3044M', 'CVotes45AM']

# %%
u=genre_top10.groupby(by=genre_top10.index)['CVotesU18M', 'CVotes1829M', 'CVotes3044M', 'CVotes45AM'].mean()


v=genre_top10.groupby(by=genre_top10.index)['CVotesU18F', 'CVotes1829F', 'CVotes3044F', 'CVotes45AF'].mean()

# %%
sns.heatmap(v,annot=True,cmap='Greens')
# Out:
# <Axes: >

# %%
sns.heatmap(u,annot=True,cmap='Greens')
# Out:
# <Axes: >

# %%
u
# Out:
#              CVotesU18M  CVotes1829M  CVotes3044M  CVotes45AM
# CVotesU18M     1.000000     0.871813     0.818448    0.774873
# CVotes1829M    0.871813     1.000000     0.994060    0.978671
# CVotes3044M    0.818448     0.994060     1.000000    0.992462
# CVotes45AM     0.774873     0.978671     0.992462    1.000000

# %%
d
# Out:
# ['CVotesU18M', 'CVotes1829M', 'CVotes3044M', 'CVotes45AM']

# %%
s.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 100 entries, 34 to 6
# Data columns (total 66 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Title                   100 non-null    object
#  1   title_year              100 non-null    int64
#  2   budget                  100 non-null    int64
#  3   Gross                   100 non-null    int64
#  4   actor_1_name            100 non-null    object
#  5   actor_2_name            100 non-null    object
#  6   actor_3_name            100 non-null    object
#  7   actor_1_facebook_likes  100 non-null    int64
#  8   actor_2_facebook_likes  99 non-null     float64
#  9   actor_3_facebook_likes  98 non-null     float64
#  10  IMDb_rating             100 non-null    float64
#  11  genre_1                 100 non-null    object
#  12  genre_2                 97 non-null     object
#  13  genre_3                 74 non-null     object
# ...

# %%
s["IFUS"]=s["Country"].apply(lambda x : "USA" if x=="USA"  else "non-USA")

# %%
s["IFUS"].value_counts()
# Out:
# USA        81
# non-USA    19
# Name: IFUS, dtype: int64

# %%
sns.boxplot(data=s,x="CVotesUS",y="IFUS")
# Out:
# <Axes: xlabel='CVotesUS', ylabel='IFUS'>

# %%
sns.boxplot(data=s,x="CVotesnUS",y="IFUS")
# Out:
# <Axes: xlabel='CVotesnUS', ylabel='IFUS'>

# %%
sns.boxplot(data=s,x="VotesUS",y="IFUS")
# Out:
# <Axes: xlabel='VotesUS', ylabel='IFUS'>

# %%
sns.boxplot(data=s,x="VotesnUS",y="IFUS")
# Out:
# <Axes: xlabel='VotesnUS', ylabel='IFUS'>

# %%
genre_top10.sort_values("CVotes1000",ascending=False)
# Out:
#                 CVotes10       CVotes09       CVotes08       CVotes07  \
# Sci-Fi     136781.411765  148873.823529  176646.705882  106005.764706
# Action     102144.096774  114433.193548  150895.322581   94262.129032
# Thriller    83207.769231  112730.076923  153336.769231   90446.076923
# Adventure   94596.289474  105636.631579  138482.315789   86367.921053
# Crime       52229.636364   87919.818182  129045.000000   74671.818182
# Comedy      60157.217391   77173.347826  108993.521739   69176.913043
# Biography   47333.500000   77867.111111  123948.777778   74054.444444
# Drama       52375.969231   75928.846154  109339.276923   66456.923077
# Animation   61960.181818   72566.090909  104837.636364   65707.454545
# Romance     42304.538462   53037.846154   82252.307692   54833.923077
#
#                CVotes06      CVotes05     CVotes04     CVotes03     CVotes02  \
# Sci-Fi     39518.294118  14951.470588  6583.823529  3876.705882  2715.941176
# ...

# %%
sns.barplot(x=genre_top10.index,y=genre_top10.CVotes1000)
# Out:
# <Axes: ylabel='CVotes1000'>
